# %% [markdown]
# # EPL Analysis - Team Segmentation

# %% [markdown]
# ## Abstract
# The goal is to analyse season statistics of EPL teams to identify possible clusters or segments which can later be used for predictive modelling.

# %% [markdown]
# ## 1. Setup my environment

# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
import pandas as pd
import FootballDataAnalysis as fda

# %%
import importlib
importlib.reload(fda)
# Out:
# <module 'FootballDataAnalysis' from 'C:\\Users\\jonat\\Workspace\\FootballPrediction\\FootballDataAnalysis.py'>

# %% [markdown]
# ## 2. Load data

# %%
# Load match data
match_data = fda.LoadMatchData()
match_data # Show
# Out:
#      Div Season        Date     HomeTeam      AwayTeam FTHG FTAG FTR HTHG  \
# 0     E0   0910    15/08/09  Aston Villa         Wigan    0    2   A    0
# 1     E0   0910    15/08/09    Blackburn      Man City    0    2   A    0
# 2     E0   0910    15/08/09       Bolton    Sunderland    0    1   A    0
# 3     E0   0910    15/08/09      Chelsea          Hull    2    1   H    1
# 4     E0   0910    15/08/09      Everton       Arsenal    1    6   A    0
# ...   ..    ...         ...          ...           ...  ...  ...  ..  ...
# 3795  E0   1819  12/05/2019    Liverpool        Wolves    2    0   H    1
# 3796  E0   1819  12/05/2019   Man United       Cardiff    0    2   A    0
# 3797  E0   1819  12/05/2019  Southampton  Huddersfield    1    1   D    1
# 3798  E0   1819  12/05/2019    Tottenham       Everton    2    2   D    1
# 3799  E0   1819  12/05/2019      Watford      West Ham    1    4   A    0
#
#      HTAG  ...  HC AC  HF  AF   HO   AO HY AY HR AR
# 0       1  ...   4  6  15  14  NaN  NaN  2  2  0  0
# 1       1  ...   5  4  12   9  NaN  NaN  2  1  0  0
# 2       1  ...   4  7  16  10  NaN  NaN  2  1  0  0
# 3       1  ...  12  4  13  15  NaN  NaN  1  2  0  0
# 4       3  ...   4  9  11  13  NaN  NaN  0  0  0  0
# ...   ...  ...  .. ..  ..  ..  ...  ... .. .. .. ..
# 3795    0  ...   4  1   3  11  NaN  NaN  0  2  0  0
# 3796    1  ...  11  2   9   6  NaN  NaN  3  3  0  0
# 3797    0  ...   4  3   8   6  NaN  NaN  0  1  0  0
# 3798    0  ...   7  4  10  13  NaN  NaN  0  2  0  0
# 3799    2  ...   7  2  10  10  NaN  NaN  1  0  1  0
#
# [3800 rows x 29 columns]

# %% [markdown]
# ## 3. Prepare Data

# %%
match_data['MatchIdx'] = match_data.index
pd.melt(match_data,
       id_vars=['MatchIdx'],
       value_vars=['HomeTeam','AwayTeam'],
       value_name='Team',
       var_name='HomeAway').merge(match_data, left_on='MatchIdx', right_on='MatchIdx', how='inner')
# Out:
#       MatchIdx  HomeAway          Team Div Season        Date     HomeTeam  \
# 0            0  HomeTeam   Aston Villa  E0   0910    15/08/09  Aston Villa
# 1            0  AwayTeam         Wigan  E0   0910    15/08/09  Aston Villa
# 2            1  HomeTeam     Blackburn  E0   0910    15/08/09    Blackburn
# 3            1  AwayTeam      Man City  E0   0910    15/08/09    Blackburn
# 4            2  HomeTeam        Bolton  E0   0910    15/08/09       Bolton
# ...        ...       ...           ...  ..    ...         ...          ...
# 7595      3797  AwayTeam  Huddersfield  E0   1819  12/05/2019  Southampton
# 7596      3798  HomeTeam     Tottenham  E0   1819  12/05/2019    Tottenham
# 7597      3798  AwayTeam       Everton  E0   1819  12/05/2019    Tottenham
# 7598      3799  HomeTeam       Watford  E0   1819  12/05/2019      Watford
# 7599      3799  AwayTeam      West Ham  E0   1819  12/05/2019      Watford
#
#           AwayTeam FTHG FTAG  ... AC  HF  AF   HO   AO HY AY HR AR match_idx
# 0            Wigan    0    2  ...  6  15  14  NaN  NaN  2  2  0  0         0
# 1            Wigan    0    2  ...  6  15  14  NaN  NaN  2  2  0  0         0
# 2         Man City    0    2  ...  4  12   9  NaN  NaN  2  1  0  0         1
# 3         Man City    0    2  ...  4  12   9  NaN  NaN  2  1  0  0         1
# 4       Sunderland    0    1  ...  7  16  10  NaN  NaN  2  1  0  0         2
# ...            ...  ...  ...  ... ..  ..  ..  ...  ... .. .. .. ..       ...
# 7595  Huddersfield    1    1  ...  3   8   6  NaN  NaN  0  1  0  0      3797
# 7596       Everton    2    2  ...  4  10  13  NaN  NaN  0  2  0  0      3798
# 7597       Everton    2    2  ...  4  10  13  NaN  NaN  0  2  0  0      3798
# 7598      West Ham    1    4  ...  2  10  10  NaN  NaN  1  0  1  0      3799
# 7599      West Ham    1    4  ...  2  10  10  NaN  NaN  1  0  1  0      3799
#
# [7600 rows x 33 columns]

# %%
def Points(result):
    points = 0
    if result=='W':
        points = 3
    elif result=='D':
        points = 1
    else:
        points = 0
    return points

def Goals(ForAgainst,HomeAway,FTHG,FTAG):
    if HomeAway=='Home':
        if ForAgainst=='For':
            return FTHG
        else:
            return FTAG
    else:
        if ForAgainst=='For':
            return FTAG
        else:
            return FTHG

def TeamMatchStatistics(match_data):
    """Match statistics by team"""
    match_data['MatchIdx'] = match_data.index
    team_match_statistics = pd.melt(match_data,
                                    id_vars=['MatchIdx'],
                                    value_vars=['HomeTeam','AwayTeam'],
                                    value_name='Team',
                                    var_name='HomeAway')\
    .merge(match_data,left_on='MatchIdx',right_on='MatchIdx',how='inner')
    team_match_statistics['HomeAway'] = team_match_statistics.apply(lambda x: x['HomeAway'].replace('Team',''),axis='columns')
    team_match_statistics['Result'] = team_match_statistics.apply(lambda x: fda._WinLossDraw(x['HomeAway'],x['FTR']),axis='columns')
    team_match_statistics['Points'] = team_match_statistics.apply(lambda x: Points(x['Result']),axis='columns')
    team_match_statistics['GS'] = team_match_statistics.apply(lambda x: Goals('For',x['HomeAway'],x['FTHG'],x['FTAG']),axis='columns')
    team_match_statistics['GC'] = team_match_statistics.apply(lambda x: Goals('Against',x['HomeAway'],x['FTHG'],x['FTAG']),axis='columns')
    team_match_statistics['GD'] = team_match_statistics.apply(lambda x: int(x['GS'])-int(x['GC']),axis='columns')
    return team_match_statistics.loc[:,['Season','Div','Team','Result','Points','GS','GC','GD']]

TeamMatchStatistics(match_data)
# Out:
#      Season Div          Team Result  Points GS GC  GD
# 0      0910  E0   Aston Villa      L       0  0  2  -2
# 1      0910  E0         Wigan      W       3  2  0   2
# 2      0910  E0     Blackburn      L       0  0  2  -2
# 3      0910  E0      Man City      W       3  2  0   2
# 4      0910  E0        Bolton      L       0  0  1  -1
# ...     ...  ..           ...    ...     ... .. ..  ..
# 7595   1819  E0  Huddersfield      D       1  1  1   0
# 7596   1819  E0     Tottenham      D       1  2  2   0
# 7597   1819  E0       Everton      D       1  2  2   0
# 7598   1819  E0       Watford      L       0  1  4  -3
# 7599   1819  E0      West Ham      W       3  4  1   3
#
# [7600 rows x 8 columns]
